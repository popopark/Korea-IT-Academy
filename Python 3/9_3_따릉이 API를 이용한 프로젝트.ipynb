# %% [markdown]
# # 1. API(Application Programming lnterface)
#
# * 여러 프로그램들과 데이터베이스, 여러 기능들의 상호 통신 방법을 정하고 도와주는 매개체

# %% [markdown]
# # 2. 따릉이 API에 접속하기

# %%
import requests
import folium
import json
from pandas.io.json import json_normalize
import warnings

warnings.filterwarnings('ignore')

# %%
targetSite = 'https://www.bikeseoul.com/app/station/getStationRealtimeStatus.do'
request = requests.post(targetSite, data={'stationGrpSeq':'ALL'})
print(request)    # <Response [200]> : 정상적인 접속 안내\
print(type(request))
print(request.text)
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {"stationImgPath":"/nas_link/spb/attachFiles/file_admin/basePath","appUserSessionVO":{"encPwd":null,"usrClsCd":null,"usrDeviceId":null,"usrSeq":null,"voucherEndDttm":null,"voucherSeq":null,"usrType":null,"loginId":null,"usrMpnNo":null,"snsType":null,"mbId":null,"mpnLostYn":null,"lang":"LAG_001","appOsType":null,"regDttm":null,"orgType":null,"snsId":null,"viewFlg":"list","usrBirthDate":null,"sexCd":null,"rentEncPwd":null,"telecomClsCd":null,"authCiVal":null,"authClsCd":null,"mbTelNo":null,"mbEmailName":null,"mbPostNo":null,"mbAddr1":null,"mbAddr2":null,"parentSexCd":null,"parentBirthDate":null,"parentMpnNo":null,"emailSendAgreeYn":null,"lastLoginDttm":null,"mbWgt":null,"langClsCd":null,"leaveYn":null,"leaveReasonCd":null,"leaveDttm":null,"mbInfoColecAgreeDttm":null,"mpnLostDttm":null,"pagingYn":null,"usrIp":null,"partyVoucherSeq":null,"elecVoucherSeq":null,"requestSeq":null,"usrDeviceType":null,"authDiVal":null,"snsEmail":null,"tCardYn":null,"mCardYn":null,"mainType":null,"totalRecordCount":0,"recordCountPerPage":0,"firstRecordIndex":0,"currentPageNo":1,"pageSize":0,"searchValue":null,"searchDate":null,"searchParameter":null,"searchStartDate":null,"searchEndDate":null,"mode":null},"loginYn":"N","realtimeList":[{"stationId":"ST-4","stationImgFileName":"","stationName":"102. 망원역 1번출구 앞","parkingBikeTotCnt":"0","parkingQRBikeCnt":"10","parkingELECBikeCnt":"1","stationLongitude":"126.91062927","stationLatitude":"37.55564880","rackTotCnt":"15","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-5","stationImgFileName":"","stationName":"103. 망원역 2번출구 앞","parkingBikeTotCnt":"0","parkingQRBikeCnt":"3","parkingELECBikeCnt":"1","stationLongitude":"126.91083527","stationLatitude":"37.55495071","rackTotCnt":"14","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-6","stationImgFileName":"","stationName":"104. 합정역 1번출구 앞","parkingBikeTotCnt":"0","parkingQRBikeCnt":"2","parkingELECBikeCnt":"0","stationLongitude":"126.91498566","stationLatitude":"37.55062866","rackTotCnt":"13","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-7","stationImgFileName":"","stationName":"105. 합정역 5번출구 앞","parkingBikeTotCnt":"0","parkingQRBikeCnt":"1","parkingELECBikeCnt":"0","stationLongitude":"126.91482544","stationLatitude":"37.55000687","rackTotCnt":"5","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-8","stationImgFileName":"","stationName":"106. 합정역 7번출구 앞","parkingBikeTotCnt":"0","parkingQRBikeCnt":"7","parkingELECBikeCnt":"0","stationLongitude":"126.91282654","stationLatitude":"37.54864502","rackTotCnt":"12","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-9","stationImgFileName":"","stationName":"107. 신한은행 서교동지점","parkingBikeTotCnt":"0","parkingQRBikeCnt":"2","parkingELECBikeCnt":"0","stationLongitude":"126.91850281","stationLatitude":"37.55751038","rackTotCnt":"5","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-10","stationImgFileName":"","stationName":"108. 서교동 사거리","parkingBikeTotCnt":"0","parkingQRBikeCnt":"5","parkingELECBikeCnt":"1","stationLongitude":"126.91861725","stationLatitude":"37.55274582","rackTotCnt":"10","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-11","stationImgFileName":"","stationName":"109. 제일빌딩 앞","parkingBikeTotCnt":"0","parkingQRBikeCnt":"0","parkingELECBikeCnt":"1","stationLongitude":"126.91998291","stationLatitude":"37.54769135","rackTotCnt":"10","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-15","stationImgFileName":"","stationName":"111. 상수역 2번출구 앞","parkingBikeTotCnt":"0","parkingQRBikeCnt":"1","parkingELECBikeCnt":"0","stationLongitude":"126.92353058","stationLatitude":"37.54787064","rackTotCnt":"10","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-16","stationImgFileName":"","stationName":"112. 극동방송국 앞","parkingBikeTotCnt":"0","parkingQRBikeCnt":"3","parkingELECBikeCnt":"0","stationLongitude":"126.92320251","stationLatitude":"37.54920197","rackTotCnt":"10","stationSeCd":"RAK_002","mode":null},{"stationId":"ST-18","stationImgFileName":"","stationName":"113. 홍대입구역 2번출구 앞","parkingB ...

# %% [markdown]
# # 3. 따릉이 데이터 분석하기

# %%
# json.loads() : json 타입의 문자열 데이터를 파이썬에서 처리 할 수 있도록 변환(딕셔너리 타입)

bike_json = json.loads(request.text)
print(bike_json)
print(type(bike_json))
# Out:
# {'stationImgPath': '/nas_link/spb/attachFiles/file_admin/basePath', 'appUserSessionVO': {'encPwd': None, 'usrClsCd': None, 'usrDeviceId': None, 'usrSeq': None, 'voucherEndDttm': None, 'voucherSeq': None, 'usrType': None, 'loginId': None, 'usrMpnNo': None, 'snsType': None, 'mbId': None, 'mpnLostYn': None, 'lang': 'LAG_001', 'appOsType': None, 'regDttm': None, 'orgType': None, 'snsId': None, 'viewFlg': 'list', 'usrBirthDate': None, 'sexCd': None, 'rentEncPwd': None, 'telecomClsCd': None, 'authCiVal': None, 'authClsCd': None, 'mbTelNo': None, 'mbEmailName': None, 'mbPostNo': None, 'mbAddr1': None, 'mbAddr2': None, 'parentSexCd': None, 'parentBirthDate': None, 'parentMpnNo': None, 'emailSendAgreeYn': None, 'lastLoginDttm': None, 'mbWgt': None, 'langClsCd': None, 'leaveYn': None, 'leaveReasonCd': None, 'leaveDttm': None, 'mbInfoColecAgreeDttm': None, 'mpnLostDttm': None, 'pagingYn': None, 'usrIp': None, 'partyVoucherSeq': None, 'elecVoucherSeq': None, 'requestSeq': None, 'usrDeviceType': None, 'authDiVal': None, 'snsEmail': None, 'tCardYn': None, 'mCardYn': None, 'mainType': None, 'totalRecordCount': 0, 'recordCountPerPage': 0, 'firstRecordIndex': 0, 'currentPageNo': 1, 'pageSize': 0, 'searchValue': None, 'searchDate': None, 'searchParameter': None, 'searchStartDate': None, 'searchEndDate': None, 'mode': None}, 'loginYn': 'N', 'realtimeList': [{'stationId': 'ST-4', 'stationImgFileName': '', 'stationName': '102. 망원역 1번출구 앞', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '10', 'parkingELECBikeCnt': '1', 'stationLongitude': '126.91062927', 'stationLatitude': '37.55564880', 'rackTotCnt': '15', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-5', 'stationImgFileName': '', 'stationName': '103. 망원역 2번출구 앞', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '3', 'parkingELECBikeCnt': '1', 'stationLongitude': '126.91083527', 'stationLatitude': '37.55495071', 'rackTotCnt': '14', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-6', 'stationImgFileName': '', 'stationName': '104. 합정역 1번출구 앞', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '2', 'parkingELECBikeCnt': '0', 'stationLongitude': '126.91498566', 'stationLatitude': '37.55062866', 'rackTotCnt': '13', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-7', 'stationImgFileName': '', 'stationName': '105. 합정역 5번출구 앞', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '1', 'parkingELECBikeCnt': '0', 'stationLongitude': '126.91482544', 'stationLatitude': '37.55000687', 'rackTotCnt': '5', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-8', 'stationImgFileName': '', 'stationName': '106. 합정역 7번출구 앞', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '7', 'parkingELECBikeCnt': '0', 'stationLongitude': '126.91282654', 'stationLatitude': '37.54864502', 'rackTotCnt': '12', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-9', 'stationImgFileName': '', 'stationName': '107. 신한은행 서교동지점', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '2', 'parkingELECBikeCnt': '0', 'stationLongitude': '126.91850281', 'stationLatitude': '37.55751038', 'rackTotCnt': '5', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-10', 'stationImgFileName': '', 'stationName': '108. 서교동 사거리', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '5', 'parkingELECBikeCnt': '1', 'stationLongitude': '126.91861725', 'stationLatitude': '37.55274582', 'rackTotCnt': '10', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-11', 'stationImgFileName': '', 'stationName': '109. 제일빌딩 앞', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '0', 'parkingELECBikeCnt': '1', 'stationLongitude': '126.91998291', 'stationLatitude': '37.54769135', 'rackTotCnt': '10', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-15', 'stationImgFileName': '', 'stationName': '111. 상수역 2번출구 앞', 'parkingBikeTotCnt': '0', 'parkingQRBikeCnt': '1', 'parkingELECBikeCnt': '0', 'stationLongitude': '126.92353058', 'stationLatitude': '37.54787064', 'rackTotCnt': '10', 'stationSeCd': 'RAK_002', 'mode': None}, {'stationId': 'ST-16', 's ...
# <class 'dict'>

# %%
# json_normalize(): 딕셔너리 타입의 데이터를 판다스 데이터 프레임으로 변환

bike_df = json_normalize(bike_json, 'realtimeList')
bike_df
# Out:
#      stationId stationImgFileName             stationName parkingBikeTotCnt  \
# 0         ST-4                            102. 망원역 1번출구 앞                 0
# 1         ST-5                            103. 망원역 2번출구 앞                 0
# 2         ST-6                            104. 합정역 1번출구 앞                 0
# 3         ST-7                            105. 합정역 5번출구 앞                 0
# 4         ST-8                            106. 합정역 7번출구 앞                 0
# ...        ...                ...                     ...               ...
# 2697   ST-3204                             5865.더리브오피스텔 앞                 0
# 2698   ST-3212                                5866.포레나 당산                 0
# 2699   ST-3235                                5867. H타워 앞                 0
# 2700   ST-3161                              6053. 중부세무서 앞                 0
# 2701   ST-3210                     6054.청구e편한세상아파트 113동 앞                 0
#
#      parkingQRBikeCnt parkingELECBikeCnt stationLongitude stationLatitude  \
# 0                  10                  1     126.91062927     37.55564880
# 1                   3                  1     126.91083527     37.55495071
# 2                   2                  0     126.91498566     37.55062866
# 3                   1                  0     126.91482544     37.55000687
# 4                   7                  0     126.91282654     37.54864502
# ...               ...                ...              ...             ...
# 2697                2                  0     126.91259766     37.51791763
# 2698                5                  0     126.89550781     37.52195358
# 2699                0                  0     126.91245270     37.52024078
# 2700                2                  0     126.99066162     37.56092453
# 2701                1                  0     127.01821136     37.56104279
#
#      rackTotCnt stationSeCd  mode
# 0            15     RAK_002  None
# 1            14     RAK_002  None
# 2            13     RAK_002  None
# 3             5     RAK_002  None
# 4            12     RAK_002  None
# ...         ...         ...   ...
# 2697         10     RAK_002  None
# 2698          8     RAK_002  None
# 2699         10     RAK_002  None
# 2700          5     RAK_002  None
# 2701          5     RAK_002  None
#
# [2702 rows x 11 columns]

# %%
bike_df.columns
# Out:
# Index(['stationId', 'stationImgFileName', 'stationName', 'parkingBikeTotCnt',
#        'parkingQRBikeCnt', 'parkingELECBikeCnt', 'stationLongitude',
#        'stationLatitude', 'rackTotCnt', 'stationSeCd', 'mode'],
#       dtype='object')

# %% [markdown]
# * stationld : 고유한 대여소 번호
#
# * stationlmgFileName :

# %% [markdown]
# * stationImgFileName: 대여소 사진
# * stationName: 대여소 이름
# * stationLongitude: 대여소 경도
# * stationLatitude: 대여소 위도
# * rackTotCnt: 주차 가능한 전체 자전거 대수
# * parkingBikeTotCnt: 주차된 따릉이 총 대수
# * parkingQRBikeCnt: 주차된 따릉이 QR형 총 대수
# * parkingELECBikeCnt: 주차된 새싹 따릉이 총 대수

# %%
bike_df_map = bike_df[['stationName', 'stationLongitude', 'stationLatitude', 'rackTotCnt',
                       'parkingBikeTotCnt', 'parkingQRBikeCnt', 'parkingELECBikeCnt']]
bike_df_map
# Out:
#                  stationName stationLongitude stationLatitude rackTotCnt  \
# 0            102. 망원역 1번출구 앞     126.91062927     37.55564880         15
# 1            103. 망원역 2번출구 앞     126.91083527     37.55495071         14
# 2            104. 합정역 1번출구 앞     126.91498566     37.55062866         13
# 3            105. 합정역 5번출구 앞     126.91482544     37.55000687          5
# 4            106. 합정역 7번출구 앞     126.91282654     37.54864502         12
# ...                      ...              ...             ...        ...
# 2697          5865.더리브오피스텔 앞     126.91259766     37.51791763         10
# 2698             5866.포레나 당산     126.89550781     37.52195358          8
# 2699             5867. H타워 앞     126.91245270     37.52024078         10
# 2700           6053. 중부세무서 앞     126.99066162     37.56092453          5
# 2701  6054.청구e편한세상아파트 113동 앞     127.01821136     37.56104279          5
#
#      parkingBikeTotCnt parkingQRBikeCnt parkingELECBikeCnt
# 0                    0               10                  1
# 1                    0                3                  1
# 2                    0                2                  0
# 3                    0                1                  0
# 4                    0                7                  0
# ...                ...              ...                ...
# 2697                 0                2                  0
# 2698                 0                5                  0
# 2699                 0                0                  0
# 2700                 0                2                  0
# 2701                 0                1                  0
#
# [2702 rows x 7 columns]

# %%
bike_df_map.dtypes
# Out:
# stationName           object
# stationLongitude      object
# stationLatitude       object
# rackTotCnt            object
# parkingBikeTotCnt     object
# parkingQRBikeCnt      object
# parkingELECBikeCnt    object
# dtype: object

# %%
bike_df_map['stationLongitude'] = bike_df_map['stationLongitude'].astype(float)
bike_df_map['stationLatitude'] = bike_df_map['stationLatitude'].astype(float)

bike_df_map['rackTotCnt'] = bike_df_map['rackTotCnt'].astype(int)
bike_df_map['parkingBikeTotCnt'] = bike_df_map['parkingBikeTotCnt'].astype(int)
bike_df_map['parkingQRBikeCnt'] = bike_df_map['parkingQRBikeCnt'].astype(int)
bike_df_map['parkingELECBikeCnt'] = bike_df_map['parkingELECBikeCnt'].astype(int)

bike_df_map['total'] = bike_df_map['parkingBikeTotCnt'] + bike_df_map['parkingQRBikeCnt'] + bike_df_map['parkingELECBikeCnt']

# %%
bike_df_map.dtypes
# Out:
# stationName            object
# stationLongitude      float64
# stationLatitude       float64
# rackTotCnt              int64
# parkingBikeTotCnt       int64
# parkingQRBikeCnt        int64
# parkingELECBikeCnt      int64
# total                   int64
# dtype: object

# %%
bike_df_map.head()
# Out:
#        stationName  stationLongitude  stationLatitude  rackTotCnt  \
# 0  102. 망원역 1번출구 앞        126.910629        37.555649          15
# 1  103. 망원역 2번출구 앞        126.910835        37.554951          14
# 2  104. 합정역 1번출구 앞        126.914986        37.550629          13
# 3  105. 합정역 5번출구 앞        126.914825        37.550007           5
# 4  106. 합정역 7번출구 앞        126.912827        37.548645          12
#
#    parkingBikeTotCnt  parkingQRBikeCnt  parkingELECBikeCnt  total
# 0                  0                10                   1     11
# 1                  0                 3                   1      4
# 2                  0                 2                   0      2
# 3                  0                 1                   0      1
# 4                  0                 7                   0      7

# %%
bike_df_map.shape
# Out:
# (2702, 8)

# %%
# 따릉이 모든 데이터를 지도에 표시하기
# 팝업 형식 -> 대여소이름 일반:X대, QR:X대, 새싹:X대
bike_map = folium.Map(location=[bike_df_map['stationLatitude'].mean(), bike_df_map['stationLongitude'].mean()], zoom_start=12)
for index, data in bike_df_map.iterrows():
    string = '{} 일반:{}대, QR:{}대, 새싹:{}대'.format(data['stationName'], data['parkingBikeTotCnt'],
                                                data['parkingQRBikeCnt'], data['parkingELECBikeCnt'])
    # print(string)
    popup = folium.Popup(string, max_width=600)
    folium.Marker(location=[data['stationLatitude'], data['stationLongitude']], popup=popup).add_to(bike_map)
bike_map
# Out:
# Output hidden; open in https://colab.research.google.com to view.
