# %%
import requests
import folium
import json
from pandas.io.json import json_normalize
import warnings

warnings.filterwarnings('ignore')

# %%
targetSite = 'https://www.starbucks.co.kr/store/getSidoList.do'
request = requests.post(targetSite, data={'stationGrpSeq':'ALL'})
print(request)    # <Response [200]> : 정상적인 접속 안내\
print(type(request))
print(request.text)
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# ...

# %%
star_json = json.loads(request.text)
print(star_json)
# Out:
# {'list': [{'seq': 0, 'sido_cd': '01', 'sido_nm': '서울', 'gugun_cd': None, 'gugun_nm': None, 'code_order': None, 'view_yn': None, 'store_num': None, 'sido': None, 'gugun': None, 'address': None, 'new_img_nm': None, 'p_pro_seq': 0, 'p_view_yn': None, 'p_sido_cd': '', 'p_gugun_cd': '', 'p_store_nm': None, 'p_theme_cd': None, 'p_wireless_yn': None, 'p_smoking_yn': None, 'p_book_yn': None, 'p_music_yn': None, 'p_terrace_yn': None, 'p_table_yn': None, 'p_takeout_yn': None, 'p_parking_yn': None, 'p_dollar_assent': None, 'p_card_recharge': None, 'p_subway_yn': None, 'stb_store_file_renew': None, 'stb_store_theme_renew': None, 'stb_store_time_renew': None, 'stb_store_lsm': None, 's_code': None, 's_name': None, 'tel': None, 'fax': None, 'sido_code': None, 'sido_name': None, 'gugun_code': None, 'gugun_name': None, 'addr': None, 'park_info': None, 'new_state': None, 'theme_state': None, 'new_bool': 0, 'search_text': '', 'ins_lat': '', 'ins_lng': '', 'in_distance': 0, 'out_distance': None, 'all_se
# ...

# %%
print(len(star_json))
print(len(star_json['list']))
# Out:
# 1
# 17

# %%
sidoList = request.json()
print(sidoList)
# Out:
# {'list': [{'seq': 0, 'sido_cd': '01', 'sido_nm': '서울', 'gugun_cd': None, 'gugun_nm': None, 'code_order': None, 'view_yn': None, 'store_num': None, 'sido': None, 'gugun': None, 'address': None, 'new_img_nm': None, 'p_pro_seq': 0, 'p_view_yn': None, 'p_sido_cd': '', 'p_gugun_cd': '', 'p_store_nm': None, 'p_theme_cd': None, 'p_wireless_yn': None, 'p_smoking_yn': None, 'p_book_yn': None, 'p_music_yn': None, 'p_terrace_yn': None, 'p_table_yn': None, 'p_takeout_yn': None, 'p_parking_yn': None, 'p_dollar_assent': None, 'p_card_recharge': None, 'p_subway_yn': None, 'stb_store_file_renew': None, 'stb_store_theme_renew': None, 'stb_store_time_renew': None, 'stb_store_lsm': None, 's_code': None, 's_name': None, 'tel': None, 'fax': None, 'sido_code': None, 'sido_name': None, 'gugun_code': None, 'gugun_name': None, 'addr': None, 'park_info': None, 'new_state': None, 'theme_state': None, 'new_bool': 0, 'search_text': '', 'ins_lat': '', 'ins_lng': '', 'in_distance': 0, 'out_distance': None, 'all_se
# ...

# %%
sido_list = dict()
for sido in star_json['list']:
    sido_list[sido['sido_cd']] = sido['sido_nm']
print(sido_list)
# Out:
# {'01': '서울', '08': '경기', '02': '광주', '03': '대구', '04': '대전', '05': '부산', '06': '울산', '07': '인천', '09': '강원', '10': '경남', '11': '경북', '12': '전남', '13': '전북', '14': '충남', '15': '충북', '16': '제주', '17': '세종'}

# %%
sido_cd = input('구군 코드를 검색 할 시도 코드를 입력하세요: ')

targetSite = 'https://www.starbucks.co.kr/store/getGugunList.do'
request = requests.post(targetSite, data={'sido_cd':sido_cd})
print(request)    # <Response [200]> : 정상적인 접속 안내\
print(type(request))
print(request.text)
# Out:
# 구군 코드를 검색 할 시도 코드를 입력하세요: 01
# <Response [200]>
# <class 'requests.models.Response'>
# ...

# %%
gugunList = json.loads(request.text)
gugun_list = dict()

for gugun in gugunList['list']:
    gugun_list[gugun['gugun_cd']] = gugun['gugun_nm']
print(gugun_list)
# Out:
# {'0101': '강남구', '0120': '강동구', '0102': '강북구', '0103': '강서구', '0104': '관악구', '0105': '광진구', '0121': '구로구', '0106': '금천구', '0107': '노원구', '0108': '도봉구', '0122': '동대문구', '0109': '동작구', '0110': '마포구', '0111': '서대문구', '0112': '서초구', '0123': '성동구', '0113': '성북구', '0114': '송파구', '0115': '양천구', '0116': '영등포구', '0124': '용산구', '0117': '은평구', '0118': '종로구', '0119': '중구', '0125': '중랑구'}

# %%
# 서울에 있는 스타벅스 전 지점

targetSite = 'https://www.starbucks.co.kr/store/getStore.do'
request = requests.post(targetSite, data={
    'ins_lat': 37.5108295,
    'ins_lng': 127.02928809999999,
    'p_sido_cd':'01',   # 01은 서울을 뜻 함
    'p_gugun_cd': '',
    'in_biz_cd': '',
    'iend':2000,
    'set_date': ''

})

start_json = request.json()
print(star_json)
print(len(star_json['list']))
# Out:
# {'list': [{'seq': 0, 'sido_cd': '01', 'sido_nm': '서울', 'gugun_cd': None, 'gugun_nm': None, 'code_order': None, 'view_yn': None, 'store_num': None, 'sido': None, 'gugun': None, 'address': None, 'new_img_nm': None, 'p_pro_seq': 0, 'p_view_yn': None, 'p_sido_cd': '', 'p_gugun_cd': '', 'p_store_nm': None, 'p_theme_cd': None, 'p_wireless_yn': None, 'p_smoking_yn': None, 'p_book_yn': None, 'p_music_yn': None, 'p_terrace_yn': None, 'p_table_yn': None, 'p_takeout_yn': None, 'p_parking_yn': None, 'p_dollar_assent': None, 'p_card_recharge': None, 'p_subway_yn': None, 'stb_store_file_renew': None, 'stb_store_theme_renew': None, 'stb_store_time_renew': None, 'stb_store_lsm': None, 's_code': None, 's_name': None, 'tel': None, 'fax': None, 'sido_code': None, 'sido_name': None, 'gugun_code': None, 'gugun_name': None, 'addr': None, 'park_info': None, 'new_state': None, 'theme_state': None, 'new_bool': 0, 'search_text': '', 'ins_lat': '', 'ins_lng': '', 'in_distance': 0, 'out_distance': None, 'all_se
# ...

# %%
star_df = json_normalize(star_json, 'list')
star_df
# Out:
#     seq sido_cd sido_nm gugun_cd gugun_nm code_order view_yn store_num  sido  \
# 0     0      01      서울     None     None       None    None      None  None
# 1     0      08      경기     None     None       None    None      None  None
# 2     0      02      광주     None     None       None    None      None  None
# 3     0      03      대구     None     None       None    None      None  None
# 4     0      04      대전     None     None       None    None      None  None
# 5     0      05      부산     None     None       None    None      None  None
# 6     0      06      울산     None     None       None    None      None  None
# 7     0      07      인천     None     None       None    None      None  None
# 8     0      09      강원     None     None       None    None      None  None
# 9     0      10      경남     None     None       None    None      None  None
# 10    0      11      경북     None     None       None    None      None  None
# ...

# %%
star_df_map = star_df[['s_name', 'sido_code', 'sido_name', 'gugun_code', 'gugun_name',
                       'doro_address', 'lat', 'lot', ]]
star_df_map
# Out:
#    s_name sido_code sido_name gugun_code gugun_name doro_address   lat   lot
# 0    None      None      None       None       None               None  None
# 1    None      None      None       None       None               None  None
# 2    None      None      None       None       None               None  None
# 3    None      None      None       None       None               None  None
# 4    None      None      None       None       None               None  None
# 5    None      None      None       None       None               None  None
# 6    None      None      None       None       None               None  None
# 7    None      None      None       None       None               None  None
# 8    None      None      None       None       None               None  None
# 9    None      None      None       None       None               None  None
# 10   None      None      None       None       None               None  None
# ...

# %%
star_df_map.dtypes
# Out:
# s_name          object
# sido_code       object
# sido_name       object
# gugun_code      object
# gugun_name      object
# doro_address    object
# lat             object
# lot             object
# dtype: object

# %%
star_df_map['lat'] = star_df_map['lat'].astype(float)
star_df_map['lot'] = star_df_map['lot'].astype(float)
star_df_map.dtypes
# Out:
# s_name           object
# sido_code        object
# sido_name        object
# gugun_code       object
# gugun_name       object
# doro_address     object
# lat             float64
# lot             float64
# dtype: object

# %%
star_df_map[star_df_map['s_name'] == '역삼아레나빌딩']
# Out:
# Empty DataFrame
# Columns: [s_name, sido_code, sido_name, gugun_code, gugun_name, doro_address, lat, lot]
# Index: []

# %%
star_df_map.isnull().sum()
# Out:
# s_name          17
# sido_code       17
# sido_name       17
# gugun_code      17
# gugun_name      17
# doro_address     0
# lat             17
# lot             17
# dtype: int64

# %%
star_df_map = star_df_map.dropna(subset=['lat', 'lot'])

# %%
star_df_map['lat'].fillna((star_df_map['lat'].mean()), inplace=True)
star_df_map['lot'].fillna((star_df_map['lot'].mean()), inplace=True)

# %%
print(star_df_map['lat'].isna().any())
print(star_df_map['lot'].isna().any())
# Out:
# False
# False

# %%
# 스타벅스 서울 전지점 지도에 출력하기
# 팝업 -> 지점 : 지점 주소

# star_map = folium.Map(location=[star_df_map['lat'].mean(), star_df_map['lot'].mean()], zoom_start=12)

# for index, data in star_df_map.iterrows():
#    popup = folium.Popup(data['s_name'] + '점 주소: ' + data['doro_address'], max_width=600)
#    folium.Marker(location=[data['lat'], data['lot']], popup=popup).add_to(star_map)
# star_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-5623e15da459> in <cell line: 9>()
#       7     popup = folium.Popup(data['s_name'] + '점 주소: ' + data['doro_address'], max_width=600)
#       8     folium.Marker(location=[data['lat'], data['lot']], popup=popup).add_to(star_map)
# ----> 9 star_map
#      10
#
# NameError: name 'star_map' is not defined
