# %% [markdown]
# #**0. 함수**
#
# * 여러줄의 코드를 재사용 하기 위해서 사용한다.
#
#       함수 정의
#
#       def 함수 이름():
#         코드
#         코드
#         ...

# %%
# 매개변수 (parameter) : 함수 소괄호 안쪽에 만들어져 있는 변수
# 매개변수 안에는 함수를 호출 할 때 소괄호 안쪽에 쓴 값(인자, 인수)이 대입된다.

def printName():    # 함수 만들기기 / ()괄호안에 변수는 아무렇게나 지정해도 됌됌
  for i in range(5):
    print('박준')

# %%
print('프로그램 개발중')    # 함수 사용(호출)

for i in range(5):
  print('박준')

printName()

print('개발중,...')

printName()
# Out:
# 프로그램 개발중
# 박준
# 박준
# 박준
# 박준
# 박준
# 박준
# 박준
# 박준
# 박준
# 박준
# 개발중,...
# 박준
# 박준
# 박준
# 박준
# 박준

# %%
# 매개변수 (parameter) : 함수 소괄호 안쪽에 만들어져 있는 변수
# 매개변수 안에는 함수를 호출 할 때 소괄호 안쪽에 쓴 값(인자, 인수)이 대입된다.
# 매개변수가 여러개라면 넘겨 받은 인자값이 순서대로 대입된다.

def printName(name, cnt):    # 함수 만들기기 / ()괄호안에 변수는 아무렇게나 지정해도 됌됌
  for i in range(cnt):
    print(name)

# %%
printName('박준', 3) # 함수 사용(호출)
print('코드 짜는 중...')
printName('박준', 2) # 함수 사용(호출)
print('코드 짜는 중...')
printName('박준', 1) # 함수 사용(호출)
print('코드 짜는 중...')
# Out:
# 박준
# 박준
# 박준
# 코드 짜는 중...
# 박준
# 박준
# 코드 짜는 중...
# 박준
# 코드 짜는 중...
