# %% [markdown]
# #**5. While문**
#
#     while문 바깥
#     while 조건식:
#       반복할 코드
#       ...
#     while문 바깥 코드
#
#   while문을 만나면
# 1. 조건식을 확인한다.
#   1-1. 조건식이 만약 True이라면 while문 안쪽 코드를 실행하고, while문이 끝나면 다시 조건식을 확인한다.
# (1번 반복)
#
#   1-2. 조건식이 만약 False 라면 while문 안쪽으로 들어가지 않는다(반복 종료)

# %%
i = 0

while i < 5:
  print('박준')

  i += 1 # i = i + 1

print('while문 바깥')
# Out:
# 박준
# 박준
# 박준
# 박준
# 박준
# while문 바깥

# %%
while True:

  num = int(input('입력 >> '))

  if num == 5:
    break

  print('while 문 안쪽')

print('while 문 바깥')
# Out:
# 입력 >> 4
# while 문 안쪽
# 입력 >> 2
# while 문 안쪽
# 입력 >> 5
# while 문 바깥

# %% [markdown]
# ##**로또 번호 추첨기**
#
# 랜덤으로 6개 숫자를 받아온다(범위는 1이상 20이하)
# - 6개의 숫자를 오름차순으로 정렬하여 보여주기
# (단 중복되는 수자는 존재하면 안된다.)

# %%
# randint() ............. randrange()......

import random # random 이라는 파일(모듈)을 사용하겠다.

# random으로 숫자를 가져오는 것
num = random.randint(1, 3) # random 파일 안에 있는 randint 라는 함수를 쓰겠다.
                     # randint(a, b) : a 이상 b이하의 정수 중에서 랜덤한 int 값을 함수 사용 결과로 return(반환)한다.

print(num)
# Out:
# 1
