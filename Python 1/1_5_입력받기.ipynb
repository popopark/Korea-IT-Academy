# %% [markdown]
# # **0. 사용자(개발자)에게 값을 입력 받기**
#
# input() 함수를 통해서 값을 입력 받을 수 있다.

# %% [markdown]
# # **1. input() 함수**
#
# * input() 함수가 실행되면 네모난 창을 통해서 값을 입력받고
# * input() 함수 사용 결과는 입력된 str 타입의 값이다*
# * input() 함수를 해석할 때는 결과 값으로 치환하여 해석한다.

# %%
print('입력 받기 시작하겠습니다~!')
print(input(), '님이 로그인 했습니다.', sep = "") #input() 함수는 사용 결과가 사용자가 입력한 str 값 이다.
print('입력 받기가 끝났습니다.')
# Out:
# 입력 받기 시작하겠습니다~!
# 박준
# 박준님이 로그인 했습니다.
# 입력 받기가 끝났습니다.

# %% [markdown]
# ## **1-1. 예제**
#
# 사용자에게 이름을 입력 받고, 다음과 같이 출력하시오
#
# 이름 입력 : 박준
#
# 지금 박준님이 접속했습니다.
# 박준님 환영합니다!

# %%
# print('이름 입력 : ', end = '')

# input() 소괄호에 str 타입 값을 넘겨주면 설명 부분에 먼저 출력하고, 입력을 받는다.

name = input()

print('지금 ', name, '님이 접속했습니다!', sep = '')
print(name, '님 환영합니다.', sep = '')
