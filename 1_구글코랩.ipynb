# %% [markdown]
# # **0.**
#
# ## 제목 : 파이썬기반AI인공지능 프로젝트1
# ## 사용 툴 : 코랩
# ## 메일 : popo.park@daum.net
#
#     제목 : 1900 파이썬 인공지능 홍길동
#     본문 : 코드 전체, 오류메시지

# %% [markdown]
# # **1. 코랩의 성능**

# %% [markdown]
# ## **1-1. OS 환경**

# %%
# !cat /etc/issue.net

# %% [markdown]
# ## **1-2. Python 버전**

# %%
# !python --version
# Out:
# Python 3.8.16

# %% [markdown]
# # **2. 셀의 종류**

# %% [markdown]
# *   코드 : 파이썬 코드를 실핼 할 수 있는 셀
# *   텍스트 : 설명을 달거나 문구들을 저장하기 위한 메모장
# (마크다운 문법 적용됨)

# %% [markdown]
# ## **2-1. 셀의 삽입 방법**
#
# 1. 상단의 버튼 클릭
# 2. 코드셀을 위에 삽입하기 : ctrl + M, A
# 3. 코드셀을 아래에 삽입하기 : ctrl + M, B

# %% [markdown]
# ## **2-2. 셀을 변경하는 방법**
#
# 1. 코드셀을 텍스트셀로 변경 : ctrl + M, M
# 2. 텍스트셀을 코드셀로 변경 : ctrl + M, Y

# %% [markdown]
# ## **2-3. 셀을 삭제하는 방법**
#
# 1. 우측 쓰레기통 아이콘 클릭
# 2. ctrl + M, D

# %% [markdown]
# ## **2-4. 단축키 설정**
#
# 1. ctrl + M, H

# %% [markdown]
# ## **3. 셀의 실행**

# %% [markdown]
# 1. 코드셀 좌측 플레이 버튼 클릭
# 2. ctrl + enter : 해당 코드셀 실행 후 그 자리에 머물기
# 3. shift + enter : 해당 코드셀 실행 후 다음 줄로 이동
# 4. alt + enter : 해당 코드셀을 실행 후 다음 셀을 삽입하고 넘어감

# %%
print('안녕하세요 반갑습니다')
# Out:
# 안녕하세요 반갑습니다

# %% [markdown]
# # **4. 이미지 다루기**

# %%
from IPython.display import Image

# %%
Image('https://t1.daumcdn.net/daumtop_chanel/op/20200723055344399.png')

# %% [markdown]
# # 5. 유튜브 동영상 로딩하기

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('7d0vg_DSYQc')

# %% [markdown]
# # **6. 파일 입력하기**

# %% [markdown]
# ## **6-1 파일 직접 드래그 & 드랍**
# 좌측 폴더 아이콘 클릭 후 파일을 직접 드래고 앤드 드랍

# %% [markdown]
# ## **6-2. 파일 직접 업로드**

# %%
from google.colab import files

# %%
myfile = files.upload()
# Out:
#      <input type="file" id="files-adedb54d-89ea-44f9-81f3-c68c526d4b76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-adedb54d-89ea-44f9-81f3-c68c526d4b76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## **6-3. 구글 드라이브에서 파일 가져오기**

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/MyDrive/0. 파이썬 기반 AI인공지능/국가보훈처 보훈의료 위탁병원 코로나-19 병원 정보_20200520.csv'

# %%
import pandas as pd  
data = pd.read_csv(filename, encoding = 'cp949')

# %%
data
# Out:
#             시군구       의료기관명  진료과수  병상수          전화번호  \
# 0       강원도 강릉시      강릉동인병원    21  608  033-651-6167
# 1       강원도 강릉시     박정빈외과의원     1    0  033-643-0080
# 2       강원도 강릉시     이명호내과의원     1    0  033-645-7747
# 3       강원도 고성군       세브란의원     4    0  033-682-7755
# 4       강원도 동해시  근로복지공단동해병원    10  499  033-530-3100
# ..          ...         ...   ...  ...           ...
# 314  충북 청주시 청원구      초정노인병원     3  150  043-213-7123
# 315  충북 청주시 흥덕구      청주현대병원     4  150  043-237-2114
# 316      충북 충주시     건국대충주병원    23  464  043-840-8200
# 317      충북 충주시      송원요양병원     2  105  043-856-3501
# 318      충북 충주시   충주시노인전문병원     4  120  043-855-9393
#
#                              주소 국민안심병원 여부 감염병전담기관 여부 감염병전담기관 외래진료 가능여부
# 0    강원도 강릉시 강릉대로419번길 42 (포남동)       NaN        NaN               NaN
# 1               강원도 강릉시 경강로2109       NaN        NaN               NaN
# 2         강원도 강릉시 솔올로 5번길40, 2층       NaN        NaN               NaN
# ...

# %% [markdown]
# # **7. 글씨체 변경하기**
#
# 1. chrome 브라우저 기준으로 우측 상단 더보기 버튼 클릭
#
# 2. 설정
#
# 3. 좌측 모양
#
# 4. 글꼴 맞춤 설정
#
# 5. 고정폭 글꼴에서 원하는 글꼴 선택
